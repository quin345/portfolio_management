# %% [markdown]
# ### DATA

# %%
from brokers import get_broker
import MetaTrader5 as mt5
import sqlite3
from datetime import datetime
import pandas as pd

class MT5DatabaseSaver:
    def __init__(self, broker_name, db_path="market_price.db"):
        self.broker_name = broker_name.lower()
        self.db_path = db_path

        # Initialize broker
        self.broker = get_broker(broker_name)
        self.broker.initialize()

        # SQLite connection
        self.conn = sqlite3.connect(self.db_path)
        self.cursor = self.conn.cursor()

        # Create broker-specific tables
        self._create_tables()

    def _table(self, base_name):
        return f"{self.broker_name}_{base_name}"

    def _create_tables(self):
        # OHLCV table
        self.cursor.execute(f"""
            CREATE TABLE IF NOT EXISTS {self._table("market_data")} (
                symbol TEXT NOT NULL,
                timeframe TEXT NOT NULL,
                timestamp TEXT NOT NULL,
                open REAL,
                high REAL,
                low REAL,
                close REAL,
                tick_volume INTEGER,
                PRIMARY KEY (symbol, timeframe, timestamp)
            )
        """)

        # Symbol metadata table (FINAL SCHEMA)
        self.cursor.execute(f"""
            CREATE TABLE IF NOT EXISTS {self._table("symbol_metadata")} (
                symbol TEXT PRIMARY KEY,
                minimal_volume REAL,
                volume_step REAL,
                margin_currency TEXT,
                profit_currency TEXT,
                contract_size REAL
            )
        """)

        self.conn.commit()

    def save_data(self, symbol, timeframe, rates):
        for rate in rates:
            time = datetime.utcfromtimestamp(int(rate['time'])).strftime("%Y-%m-%d %H:%M:%S")

            self.cursor.execute(f"""
                INSERT OR IGNORE INTO {self._table("market_data")}
                (symbol, timeframe, timestamp, open, high, low, close, tick_volume)
                VALUES (?, ?, ?, ?, ?, ?, ?, ?)
            """, (
                str(symbol),
                str(timeframe),
                time,
                float(rate['open']),
                float(rate['high']),
                float(rate['low']),
                float(rate['close']),
                int(rate['tick_volume'])
            ))

        self.conn.commit()

    def update_db(self, symbol="EURUSD", timeframe=mt5.TIMEFRAME_M1, num_bars=10):
        if not mt5.initialize():
            raise RuntimeError("MT5 initialization failed")

        rates = mt5.copy_rates_from_pos(symbol, timeframe, 0, num_bars)
        if rates is None or len(rates) == 0:
            mt5.shutdown()
            raise ValueError(f"No data returned for {symbol} on timeframe {timeframe}")

        closed_rates = rates[:-1]  # drop last forming candle

        self.save_data(symbol, timeframe, closed_rates)
        self.save_symbol_info(symbol)

        mt5.shutdown()

    def save_symbol_info(self, symbol="EURUSD"):
        if not mt5.initialize():
            raise RuntimeError("MT5 initialization failed")

        info = mt5.symbol_info(symbol)
        if info is None:
            mt5.shutdown()
            raise ValueError(f"Symbol {symbol} not found")

        # Insert metadata including contract size
        self.cursor.execute(f"""
            INSERT OR REPLACE INTO {self._table("symbol_metadata")}
            (symbol, minimal_volume, volume_step, margin_currency, profit_currency, contract_size)
            VALUES (?, ?, ?, ?, ?, ?)
        """, (
            info.name,
            float(info.volume_min),
            float(info.volume_step),
            getattr(info, "currency_margin", None),
            getattr(info, "currency_profit", None),
            float(info.trade_contract_size)
        ))

        self.conn.commit()
        mt5.shutdown()

    def load_ohlcv(self, symbol="EURUSD", timeframe="1", limit=500):
        table_name = self._table("market_data")
        query = f"""
            SELECT timestamp, open, high, low, close, tick_volume
            FROM {table_name}
            WHERE symbol = ? AND timeframe = ?
            ORDER BY timestamp ASC
            LIMIT ?
        """

        df = pd.read_sql_query(query, self.conn, params=(symbol, timeframe, limit))
        df.rename(columns={"tick_volume": "volume"}, inplace=True)
        df["timestamp"] = pd.to_datetime(df["timestamp"], utc=True)
        df.set_index("timestamp", inplace=True)

        return df

    def load_symbol_info(self, symbol="EURUSD"):
        table_name = self._table("symbol_metadata")
        query = f"""
            SELECT *
            FROM {table_name}
            WHERE symbol = ?
        """

        df = pd.read_sql_query(query, self.conn, params=(symbol,))
        if df.empty:
            return None
        return df.iloc[0].to_dict()

    def close(self):
        self.conn.close()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pandas as pd
import MetaTrader5 as mt5

acg = MT5DatabaseSaver("acg")

symbols = (
    pd.read_csv("acg_macro_signal.csv", sep="\t", header=None)[0]
      .str.lstrip("\ufeff")
      .str.strip()
      .to_list()
)

for s in symbols:
    acg.update_db(symbol=s, timeframe=mt5.TIMEFRAME_M15, num_bars=2100)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pandas as pd

# 1. Load symbols directly with pandas
symbols = pd.read_csv("acg_macro_signal.csv", sep="\t", header=None)[0].tolist()

# 2. Fetch OHLCV and combine close prices
all_closes = pd.DataFrame({
    sym: acg_data.load_ohlcv(symbol=sym, timeframe="16408", limit=100000)["close"]
    for sym in symbols
})

all_closes = all_closes.tail(60)

# %%
all_df = all_closes

# %%
from mapper import build_fx_map

fx_map, fx_exempt = build_fx_map(all_df)

# %%
import numpy as np

log_returns = np.log(all_df / all_df.shift(1)).dropna()

# %%
from covariance import ewma_cov

cov = ewma_cov(log_returns)

# %%
volatility = np.sqrt(np.diag(cov))
volatility = pd.Series(volatility, index=cov.columns)

print(volatility)
# Out:
# AUDUSD.pro     0.005406
# EURUSD.pro     0.004917
# GBPUSD.pro     0.004844
# NZDUSD.pro     0.005674
# USDCAD.pro     0.003729
# USDCHF.pro     0.007297
# USDJPY.pro     0.006608
# XAGUSD.pro     0.038822
# XAUUSD.pro     0.016879
# EUSTX50.pro    0.007194
# GER30.pro      0.007755
# HK50.pro       0.009774
# JPN225.pro     0.014035
# NAS100.pro     0.009035
# UK100.pro      0.005680
# UKOIL.pro      0.017946
# US30.pro       0.006612
# US500.pro      0.006181
# USOIL.pro      0.018701
# dtype: float64

# %%
import pandas as pd

# 1. Load ranking CSV (no header, whitespace‑delimited)
ranking = pd.read_csv(
    "acg_macro_signal.csv",
    header=None,
    sep="\t"
)

# Assign column names
ranking.columns = ["asset", "score"]

# Set asset as index
ranking = ranking.set_index("asset")

# Ensure score is numeric
ranking["score"] = pd.to_numeric(ranking["score"], errors="coerce")

# 2. Load volatility (your existing Series)
vol = volatility   # must be indexed by asset name

# 3. Align ranking with volatility index
ranking = ranking.reindex(vol.index)

# 4. Compute risk‑adjusted weights
raw_weights = ranking["score"] / vol
weights = raw_weights / raw_weights.abs().sum()

weights.to_csv("macro_weights.csv", sep=",", header=None)

# %% [markdown]
# ### SIGNAL

# %%
import MetaTrader5 as mt5
import pandas as pd
from data import MT5DatabaseSaver
from MLmodel import evaluate_symbol

acg_data = MT5DatabaseSaver("acg")

# Load symbols list
symbols = pd.read_csv("acg_active_symbols.csv", header=None, sep="\t")[0].tolist()

results = []

for symbol in symbols:
    print(f"Processing {symbol}...")

    # Update database for this symbol
    acg_data.update_db(
        symbol=str(symbol),
        timeframe=mt5.TIMEFRAME_M30,
        num_bars=10
    )

        # Load your data
    df = acg_data.load_ohlcv(
        symbol=str(symbol),
        timeframe="15",
        limit=100000
    )

    # Compute the midpoint
    mid = len(df) // 2

    # Split into two halves
    df_first_half = df.iloc[:mid]
    df_second_half = df.iloc[mid:]

    if df is None or df.empty:
        print(f"⚠️ No data for {symbol}, skipping.")
        continue

    # Evaluate symbol
    report, label_stats, threshold = evaluate_symbol(df, stddev=1)

    # Store results
    results.append({
        "symbol": str(symbol),
        "threshold": threshold,
        "report": str(report),          # convert to string for CSV
        "label_stats": str(label_stats) # convert to string for CSV
    })

acg_data.close()

# Convert results to DataFrame
df_results = pd.DataFrame(results)

# Export to CSV
df_results.to_csv("acg_results.csv", index=False)

print("Results saved to acg_results.csv")
# Out:
# Processing AUDUSD.pro...
# threshold: 0.06%
# Raw class weights: {0: 0.41405170712453127, 1: 3.3784219001610305, -1: 3.462046204620462}
# Processing EURUSD.pro...
# threshold: 0.04%
# Raw class weights: {0: 0.4253852392538524, 1: 2.975886524822695, -1: 3.193302891933029}
# Processing GBPUSD.pro...
# threshold: 0.04%
# Raw class weights: {0: 0.42746536267318663, -1: 2.9138888888888888, 1: 3.15015015015015}
# Processing NZDUSD.pro...
# threshold: 0.06%
# Raw class weights: {0: 0.4322208487845076, -1: 2.8198924731182795, 1: 3.014367816091954}
# Processing USDCAD.pro...
# threshold: 0.04%
# Raw class weights: {0: 0.4187624750499002, 1: 3.2527131782945737, -1: 3.2832550860719873}
# Processing USDCHF.pro...
# threshold: 0.06%
# Raw class weights: {0: 0.42204787769060553, 1: 3.0672514619883042, -1: 3.2832550860719873}
# Processing USDJPY.pro...
# threshold: 0.06%
# Raw class weights: {0: 0.40076408787010503, -1: 3.800724637681159, 1: 4.1380670611439845}
# Processing XAGUSD.pro...
# threshold: 0.60%
# Raw class weights: {0: 0.4033064206074587, -1: 3.759856630824373, 1: 3.9288389513108615}
# Processing XAUUSD.pro...
# threshold: 0.24%
# Raw class weights: {0: 0.3819406517385764, -1: 4.856481481481482, 1: 5.685636856368563}
# Processing EUSTX50.pro...
# threshold: 0.09%
# Raw class weights: {0: 0.4182615629984051, -1: 3.2527131782945737, 1: 3.3143759873617693}
# Processing GER30.pro...
# threshold: 0.09%
# Raw class weights: {0: 0.41356199487482753, -1: 3.394822006472492, 1: 3.4792703150912105}
# Processing HK50.pro...
# threshold: 0.12%
# Raw class weights: {0: 0.4162698412698413, -1: 3.1360239162929746, 1: 3.5863247863247865}
# Processing JPN225.pro...
# threshold: 0.13%
# Raw class weights: {0: 0.4160222090025778, -1: 3.2832550860719873, 1: 3.4281045751633985}
# Processing NAS100.pro...
# threshold: 0.10%
# Raw class weights: {0: 0.4061169183120403, -1: 3.680701754385965, 1: 3.759856630824373}
# Processing UK100.pro...
# threshold: 0.07%
# Raw class weights: {0: 0.4248683677602268, -1: 2.9138888888888888, 1: 3.29874213836478}
# Processing UKOIL.pro...
# threshold: 0.21%
# Raw class weights: {0: 0.4182615629984051, -1: 3.0672514619883042, 1: 3.531986531986532}
# Processing US30.pro...
# threshold: 0.08%
# Raw class weights: {0: 0.40447272026219394, -1: 3.78018018018018, 1: 3.800724637681159}
# Processing US500.pro...
# threshold: 0.07%
# Raw class weights: {0: 0.4063528956033314, -1: 3.680701754385965, 1: 3.7397504456327986}
# Processing USOIL.pro...
# threshold: 0.23%
# Raw class weights: {0: 0.42204787769060553, -1: 2.988603988603989, 1: 3.3784219001610305}
# Results saved to acg_results.csv

# %%
from MLmodel import generate_features
import xgboost as xgb
import MetaTrader5 as mt5
from data import MT5DatabaseSaver
import numpy as np

acg_data = MT5DatabaseSaver("acg")
symbol = "XAUUSD.pro"
df = acg_data.load_ohlcv(
        symbol=str(symbol),
        timeframe="30",
        limit=100000
)
mid = len(df) // 2

# Split into two halves
df_first_half = df.iloc[:mid]
df_second_half = df.iloc[mid:]

acg_data.update_db(symbol=str(symbol), timeframe=mt5.TIMEFRAME_M30, num_bars=300)
#df_live = acg_data.load_ohlcv(symbol="EURUSD", timeframe="30", limit=100000)

model = xgb.XGBClassifier()
model.load_model("xgb_multiclass.json")


features = generate_features(df_second_half)

features = features.dropna()

X_live = features.values

prediction = model.predict(X_live)

# MAP BACK TO TRADING LABELS
inv_map = {0: -1, 1: 0, 2: 1}
y_pred = np.vectorize(inv_map.get)(prediction)

print(y_pred)
print(df_second_half.head(1))
print(df_second_half.tail(1))
# --- IGNORE ---
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import numpy as np

values, counts = np.unique(y_pred, return_counts=True)
print(values)
print(counts)
# Out:
# [-1  0  1]
# [124  49 877]

# %% [markdown]
# ### UTILS

# %% [markdown]
# ### BACKTEST

# %% [markdown]
# ### RISK

# %% [markdown]
# ### EXECUTION

# %% [markdown]
# ### POTFOLIO ANALYTICS
